# %%
import random
game_list = ['stone', 'paper', 'scissors']
games_number = 7 # maximum number of games
games_to_win = 3 # number of games to win

# Human player picks
def choice():
    while True:
        try:
            x = input('Please enter stone, paper or scissors: ')
        except ValueError:
            print("Sorry, I didn't understand that.")
            continue
        if (x == 'paper') or ( x == 'stone') or (x == 'scissors'):
            return x
            break
        else:
            print('Please enter again')

# Machine random choice
def game(list):
    return random.choice(list)

# Human vs Machine
def combat():
    x = game(game_list) # Macnine's pick
    y = choice() # Human's pick
    if (x == 'stone') and (y == 'paper'):
        print("Machine's pick: ", x)
        return 2
    elif (x == 'stone') and (y == 'scissors'):
        print("Machine's pick: ", x)
        return 1
    elif (x == 'stone') and (y == 'stone'):
        print("Machine's pick: ", x)
        return 0
    elif (x == 'paper') and (y == 'paper'):
        print("Machine's pick: ", x)
        return 0
    elif (x == 'paper') and (y == 'scissors'):
        print("Machine's pick: ", x)
        return 2
    elif (x == 'paper') and (y == 'stone'):
        print("Machine's pick: ", x)
        return 1
    elif (x == 'scissors') and (y == 'paper'):
        print("Machine's pick: ", x)
        return 1
    elif (x == 'scissors') and (y == 'scissors'):
        print("Machine's pick: ", x)
        return 0
    elif (x == 'scissors') and (y == 'stone'):
        print("Machine's pick: ", x)
        return 2
    
def score():
    x = 0 # Machine win
    y = 0 # Human win
    for i in range(games_number):
        z = combat()
        if z == 1:
            x += 1
            print('Current score Machine vs Human ', x,':',y)
        elif z == 2:
            y += 1
            print('Current score Machine vs Human ', x,':',y)
        elif z == 0:
            print('Current score Machine vs Human ', x,':',y)
        if x == games_to_win:
            print ('Machine win!')
            break
        elif y == games_to_win:
            print ('Human win!')
            break

score()
# Out:
# Please enter stone, paper or scissors: paper
# Machine's pick:  paper
# Current score Machine vs Human  0 : 0
# Please enter stone, paper or scissors: stone
# Machine's pick:  paper
# Current score Machine vs Human  1 : 0
# Please enter stone, paper or scissors: paper
# Machine's pick:  scissors
# Current score Machine vs Human  2 : 0
# Please enter stone, paper or scissors: scissors
# Machine's pick:  scissors
# Current score Machine vs Human  2 : 0
# Please enter stone, paper or scissors: stone
# Machine's pick:  paper
# Current score Machine vs Human  3 : 0
# Machine win!

# %%
import random
game_list = ['stone', 'paper', 'scissors', 'lizard', 'spock']

def odd_input():
    while True:
        try:
            x = input('Please enter odd number: ')
        except ValueError:
            print("Sorry, I didn't understand that.")
            continue
        if int(x) % 2 != 0:
            return x
            break
        else:
            print('Please enter again')

games_number = int(odd_input()) # maximum number of games
games_to_win = round(games_number/3) + 1 # number of games to win

# Machine random choice
def game(list):
    return random.choice(list)

# Human player picks
def choice():
    while True:
        try:
            x = input('Please enter stone, paper, scissors, lizard or spock: ')
        except ValueError:
            print("Sorry, I didn't understand that.")
            continue
        if (x == 'paper') or ( x == 'stone') or (x == 'scissors') or (x == 'lizard') or (x == 'spock'):
            return x
            break
        else:
            print('Please enter again')

# Human vs Machine
def combat():
    x = game(game_list) # Macnine's pick
    y = choice() # Human's pick
    if (x == 'stone') and (y == 'paper'):
        print("Machine's pick: ", x)
        return 2
    elif (x == 'stone') and (y == 'scissors'):
        print("Machine's pick: ", x)
        return 1
    elif (x == 'stone') and (y == 'stone'):
        print("Machine's pick: ", x)
        return 0
    elif (x == 'stone') and (y == 'lizard'):
        print("Machine's pick: ", x)
        return 1
    elif (x == 'stone') and (y == 'spock'):
        print("Machine's pick: ", x)
        return 2
    elif (x == 'paper') and (y == 'paper'):
        print("Machine's pick: ", x)
        return 0
    elif (x == 'paper') and (y == 'scissors'):
        print("Machine's pick: ", x)
        return 2
    elif (x == 'paper') and (y == 'stone'):
        print("Machine's pick: ", x)
        return 1
    elif (x == 'paper') and (y == 'spock'):
        print("Machine's pick: ", x)
        return 1
    elif (x == 'paper') and (y == 'lizard'):
        print("Machine's pick: ", x)
        return 2
    elif (x == 'scissors') and (y == 'paper'):
        print("Machine's pick: ", x)
        return 1
    elif (x == 'scissors') and (y == 'scissors'):
        print("Machine's pick: ", x)
        return 0
    elif (x == 'scissors') and (y == 'stone'):
        print("Machine's pick: ", x)
        return 2
    elif (x == 'scissors') and (y == 'lizard'):
        print("Machine's pick: ", x)
        return 1
    elif (x == 'scissors') and (y == 'spock'):
        print("Machine's pick: ", x)
        return 2
    elif (x == 'lizard') and (y == 'lizard'):
        print("Machine's pick: ", x)
        return 0
    elif (x == 'lizard') and (y == 'paper'):
        print("Machine's pick: ", x)
        return 1
    elif (x == 'lizard') and (y == 'spock'):
        print("Machine's pick: ", x)
        return 1
    elif (x == 'lizard') and (y == 'stone'):
        print("Machine's pick: ", x)
        return 2
    elif (x == 'lizard') and (y == 'scissors'):
        print("Machine's pick: ", x)
        return 2
    elif (x == 'spock') and (y == 'spock'):
        print("Machine's pick: ", x)
        return 0
    elif (x == 'spock') and (y == 'paper'):
        print("Machine's pick: ", x)
        return 2
    elif (x == 'spock') and (y == 'stone'):
        print("Machine's pick: ", x)
        return 1
    elif (x == 'spock') and (y == 'scissors'):
        print("Machine's pick: ", x)
        return 1
    elif (x == 'spock') and (y == 'lizard'):
        print("Machine's pick: ", x)
        return 2

def score():
    x = 0 # Machine win
    y = 0 # Human win
    for i in range(games_number):
        z = combat()
        if z == 1:
            x += 1
            print('Current score Machine vs Human ', x,':',y)
        elif z == 2:
            y += 1
            print('Current score Machine vs Human ', x,':',y)
        elif z == 0:
            print('Current score Machine vs Human ', x,':',y)
        if x == games_to_win:
            print ('Machine win!')
            break
        elif y == games_to_win:
            print ('Human win!')
            break

score()
# Out:
# Please enter odd number: 5
# Please enter stone, paper, scissors, lizard or spock: spock
# Machine's pick:  lizard
# Current score Machine vs Human  1 : 0
# Please enter stone, paper, scissors, lizard or spock: paper
# Machine's pick:  spock
# Current score Machine vs Human  1 : 1
# Please enter stone, paper, scissors, lizard or spock: stone
# Machine's pick:  spock
# Current score Machine vs Human  2 : 1
# Please enter stone, paper, scissors, lizard or spock: lizard
# Machine's pick:  stone
# Current score Machine vs Human  3 : 1
# Machine win!
